# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi"

querystring = {"q":"get:new7:US","p":"1","t":"ns","st":"adv"}

headers = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': "54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"COUNT":"94","ITEMS":[{"netflixid":"81252169","title":"&#x62F;&#x641;&#x639;&#x629; &#x627;&#x644;&#x642;&#x627;&#x647;&#x631;&#x629;","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABdtIqznyJnYowDViAzedNql6DkZBEIVXWADhC8UgjPQykqN9Uwjthun-8DPu3xNQEtQ7LDXjm2OwTF1IG2cj8QzCQdKGjA_Z5lGTICMxThNcgg.jpg?r=bef","synopsis":"A group of women leaves Kuwait to attend university in Cairo, embarking on personal journeys filled with romance and self-discovery.<br><b>New on 2020-04-25</b>","rating":"","type":"series","released":"2019","runtime":"","largeimage":"","unogsdate":"2020-04-25","imdbid":"","download":"0"},{"netflixid":"70177496","title":"No Direction Home: Bob Dylan","image":"http://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABXWa0lv7pKOSY27EkR0baN7bo_ttcunwRXqZfdpHXjKm23KuQa0x1_CmYuq_Ub-xfuGa2-TveCze7kjerZgGpICFGg.jpg?r=50f","synopsis":"Featuring rare concert footage and interviews with legendary musicians, this documentary traces Bob Dylan&#39;s life story and extraordinary career.<br><b>New on 2020-04-25</b>","rating":"","type":"movie","released":"2005","runtime":"3h28m","largeimage":"","unogsdate":"2020-04-25","imdbid":"","download":"0"},{"netflixid":"81232663","title":"5Gang","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABVW1bvwcFLeNVvNnH-bHxfx7tabSiLkrP1NlcTKiu-YKTd1wD7GlO6l6vUyqmOkwkGU7UwmcuS2e0JwGzBBKvOmXww.jpg?r=955","synopsis":"To keep the band together, Selly tries to earn money by making an appearance at the birthday party of a mobster&#39;s daughter &mdash; until he gets kidnapped.<br><b>New on 2020-04-27</b>","rating":"","type":"movie","released":"2019","runtime":"1h35m","largeimage":"","unogsdate":"2020-04-27","imdbid":"","download":"0"},{"netflixid":"70138789","title":"Battle: Los Angeles","image":"https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYv8dRB5BolpwhYp1QAFnjKtb9MO9hjP4HAJ9tPNWM5usxcpdBJuk2ifRshNrTcWNeW2-AWTfWvwlCkveiRNZVv1EA.jpg?r=813","synopsis":"Led by their skillful staff sergeant, a platoon of gutsy Marines fights to protect all humankind from astonishingly powerful aliens.<br><b>New on 2020-04-27</b>","rating":"4.5","type":"movie","released":"2011","runtime":"1h56m","largeimage":"http://cdn0.nflximg.net/images/5828/9715828.jpg","unogsdate":"2020-04-27","imdbid":"tt2359006","download":"1"},{"netflixid":"81254577","title":"Boushkash","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWMH4lmTFj-TcHy9CP7XqnD1Ugv4tiZO40OLXa9jg56OIWISHMEKVL45QKzxTIb8cFTQN-zVOIBjdBygU3nf1MvunA.jpg?r=f0e","synopsis":"A former goalkeeper-turned-talent scout embarks on a mischievous adventure to recruit players for Egyptian football clubs.<br><b>New on 2020-04-27</b>","rating":"4.1","type":"movie","released":"2008","runtime":"1h40m","largeimage":"","unogsdate":"2020-04-27","imdbid":"tt1272034","download":"0"},{"netflixid":"81254788","title":"&#x641;&#x627;&#x635;&#x644; &#x648;&#x646;&#x639;&#x648;&#x62F;","image":"https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABQRVfeeszINJq_GJfrcNavZPs5tnVnqvo67-Ug-1Oy9iNnX-_U5L6HSPrelI81nBxzUq4R32h3zTwICzguTWiJ-yQctTD8tyEC9MIP5R-iUPDQ.jpg?r=a5f","synopsis":"While fighting a child custody battle against his father-in-law, a taxi driver loses his memory when his son is kidnapped.<br><b>New on 2020-04-27</b>","rating":"","type":"movie","released":"2012","runtime":"1h46m","largeimage":"","unogsdate":"2020-04-27","imdbid":"","download":"0"},{"netflixid":"81278142","title":"The Lift Boy","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfsOC8yai_QwafhZxAcxQgzFL4Nh1vAbJOWAOKGnVrObYkNCkKpYFvEWKK4aQgvif3XoIJB5M9pQbAUh4Le6ddAf2w.jpg?r=dff","synopsis":"When a lazy young man replaces his father as the elevator operator of a posh residential complex, what he sees as menial work soon takes on new meaning.<br><b>New on 2020-04-27</b>","rating":"","type":"movie","r ...

# %%
netflix = response.json()
netflix
# Out:
# {'COUNT': '94',
#  'ITEMS': [{'netflixid': '81252169',
#    'title': '&#x62F;&#x641;&#x639;&#x629; &#x627;&#x644;&#x642;&#x627;&#x647;&#x631;&#x629;',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABdtIqznyJnYowDViAzedNql6DkZBEIVXWADhC8UgjPQykqN9Uwjthun-8DPu3xNQEtQ7LDXjm2OwTF1IG2cj8QzCQdKGjA_Z5lGTICMxThNcgg.jpg?r=bef',
#    'synopsis': 'A group of women leaves Kuwait to attend university in Cairo, embarking on personal journeys filled with romance and self-discovery.<br><b>New on 2020-04-25</b>',
#    'rating': '',
#    'type': 'series',
#    'released': '2019',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-25',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70177496',
#    'title': 'No Direction Home: Bob Dylan',
#    'image': 'http://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABXWa0lv7pKOSY27EkR0baN7bo_ttcunwRXqZfdpHXjKm23KuQa0x1_CmYuq_Ub-xfuGa2-TveCze7kjerZgGpICFGg.jpg?r=50f',
#    'synopsis': 'Featuring rare concert footage and interviews with legendary musicians, this documentary traces Bob Dylan&#39;s life story and extraordinary career.<br><b>New on 2020-04-25</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2005',
#    'runtime': '3h28m',
#    'largeimage': '',
#    'unogsdate': '2020-04-25',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81232663',
#    'title': '5Gang',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABVW1bvwcFLeNVvNnH-bHxfx7tabSiLkrP1NlcTKiu-YKTd1wD7GlO6l6vUyqmOkwkGU7UwmcuS2e0JwGzBBKvOmXww.jpg?r=955',
#    'synopsis': 'To keep the band together, Selly tries to earn money by making an appearance at the birthday party of a mobster&#39;s daughter &mdash; until he gets kidnapped.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h35m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70138789',
#    'title': 'Battle: Los Angeles',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYv8dRB5BolpwhYp1QAFnjKtb9MO9hjP4HAJ9tPNWM5usxcpdBJuk2ifRshNrTcWNeW2-AWTfWvwlCkveiRNZVv1EA.jpg?r=813',
#    'synopsis': 'Led by their skillful staff sergeant, a platoon of gutsy Marines fights to protect all humankind from astonishingly powerful aliens.<br><b>New on 2020-04-27</b>',
#    'rating': '4.5',
#    'type': 'movie',
#    'released': '2011',
#    'runtime': '1h56m',
#    'largeimage': 'http://cdn0.nflximg.net/images/5828/9715828.jpg',
#    'unogsdate': '2020-04-27',
#    'imdbid': 'tt2359006',
#    'download': '1'},
#   {'netflixid': '81254577',
#    'title': 'Boushkash',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWMH4lmTFj-TcHy9CP7XqnD1Ugv4tiZO40OLXa9jg56OIWISHMEKVL45QKzxTIb8cFTQN-zVOIBjdBygU3nf1MvunA.jpg?r=f0e',
#    'synopsis': 'A former goalkeeper-turned-talent scout embarks on a mischievous adventure to recruit players for Egyptian football clubs.<br><b>New on 2020-04-27</b>',
#    'rating': '4.1',
#    'type': 'movie',
#    'released': '2008',
#    'runtime': '1h40m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': 'tt1272034',
#    'download': '0'},
#   {'netflixid': '81254788',
#    'title': '&#x641;&#x627;&#x635;&#x644; &#x648;&#x646;&#x639;&#x648;&#x62F;',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABQRVfeeszINJq_GJfrcNavZPs5tnVnqvo67-Ug-1Oy9iNnX-_U5L6HSPrelI81nBxzUq4R32h3zTwICzguTWiJ-yQctTD8tyEC9MIP5R-iUPDQ.jpg?r=a5f',
#    'synopsis': 'While fighting a child custody battle against his father-in-law, a taxi driver loses his memory when his son is kidnapped.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2012',
#    'runtime': '1h46m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81278142',
#    'title': 'The Lift Boy',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfsOC8yai_QwafhZxAcxQgzFL4Nh1vAbJOWAOKGnVrObYkNCkKpYFvEWKK4aQgvif3XoIJB5M9pQbAUh4Le6ddAf2w.jpg?r=dff',
#    'synopsis': 'When a lazy young man replaces his father as the elevator operator of a posh residential complex, what he sees as menial work soon takes on new meaning.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h46m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81273378',
#    'title': 'Coronavirus, Explained',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZkk1Dyb7t6FREBfqSgVoBtGDShmdStA0cf7_415BuNbYaAjInwkMIjKfzMolXTVvxsCjzqvf6eXc4n5aIgaHlcmbAYiwZMmxOHHOZv5di-cp7SAzUG42lDIbLs.jpg?r=fc4',
#    'synopsis': 'In 2020, the world changed. This topical series examines the coronavirus pandemic, the efforts to combat it and ways to manage its mental health toll.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'show',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80179190',
#    'title': 'Never Have I Ever',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABS9b0Rk2RTGXa_uyaG8t0agsKdiv-tE8A23O4kkWeGp_vfFkyJW93e2_J4d2mrjGvL2SlyX3CoAAao8iWHm1SwrJBuY7Av3UkTCwDfVvbMsc1Ko4KS2vWICoNCI.jpg?r=1ac',
#    'synopsis': 'After a traumatic year, all an Indian-American teen wants is to go from pariah to popular &mdash; but friends, family and feelings won&rsquo;t make it easy on her.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'show',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81254749',
#    'title': 'Lembi 8 Giga',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABQfSDX6o6LmQsnXwJrCmk-ckfj1th_VyYnznIt_Ys8XNFObbo7U0p5O9KOWDkIg-VfP3cwyICaqO5Xl24cY5Ve2qObBpMp1Q-nt5fZLC4S_85A.jpg?r=619',
#    'synopsis': 'To upgrade his life, a simple man fakes his credentials as a lawyer when sudden extraordinary abilities give him the talent to thrive.<br><b>New on 2020-04-27</b>',
#    'rating': '5.7',
#    'type': 'movie',
#    'released': '2010',
#    'runtime': '1h51m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': 'tt6449770',
#    'download': '0'},
#   {'netflixid': '81113920',
#    'title': 'Love Aaj Kal',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdALNZIYGNLacmMPdw9lBE8wgFoEapsIhE5rx45zwi-RbJpyGqB-iIBucQ9HDTmOzEEXmtIZN5LHs4t0g_M0e54z1Q.jpg?r=876',
#    'synopsis': 'When professional ambitions clash with personal feelings for a modern-day couple, a love story from a bygone decade may offer some wisdom.<br><b>New on 2020-04-27</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '2h19m',
#    'largeimage': '',
#    'unogsdate': '2020-04-27',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80227115',
#    'title': 'Bir Baba Hindu',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQjv7LHjRrX7TLw_Pu6Bav1JqWnvqDC15Ou7pBT2GKB7bHwrUnDCJ6eCTZQf934020XdPfG5SDVL7Sv6k5rBHwUoDw.jpg?r=8ac',
#    'synopsis': 'A Istanbul mobster falls for an Indian yoga instructor whose abduction takes him on a wild rescue mission to Mumbai.<br><b>New on 2020-04-28</b>',
#    'rating': '2.9',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h47m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt5608972',
#    'download': '0'},
#   {'netflixid': '80134603',
#    'title': 'Beynelmilel',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABct7RWojjG89YrVDmlDWHzn9Q4vNAfwo_WcDx2Cmg4UWxYNIgYAi23Kdwl_rs4Q0PPJGuYcDSnnEUulyY70D-hVIOw.jpg?r=dbc',
#    'synopsis': 'When a local musician and his band are forced to perform in honor of a right-wing coup, his daughter schemes to make their music subversive instead.<br><b>New on 2020-04-28</b>',
#    'rating': '7.2',
#    'type': 'movie',
#    'released': '2006',
#    'runtime': '1h41m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt0893507',
#    'download': '0'},
#   {'netflixid': '80134517',
#    'title': 'The Plane Tree',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbxBfzdv_LLE7KFCTwzZY3NJE6jTZ5vkkYgAkL7kHVvYE0hmXAMV5huxFSCMEvXThaI3529pQcoXSKhcSdQcQOxECQ.jpg?r=bb3',
#    'synopsis': 'A matriarch and her grandson forge a special bond during family picnics every two months, until her health causes a conflict among the relatives.<br><b>New on 2020-04-28</b>',
#    'rating': '6.1',
#    'type': 'movie',
#    'released': '2011',
#    'runtime': '1h54m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt1727564',
#    'download': '0'},
#   {'netflixid': '80227113',
#    'title': 'Ek&#x15F;i Elmalar',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcTS0Q1TYvnZXK5Z-nq1pgnyddTHLHqOKFPsResMbX5OBruYe3sIl9blEkTCoh4RFLc4Fvi86F-mw9Fc_ftuuwz3ag.jpg?r=85f',
#    'synopsis': 'In an eastern Turkish town, suitors knock on the door of the mayor and father of three beautiful daughters who choose to follow their own paths.<br><b>New on 2020-04-28</b>',
#    'rating': '7.1',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h49m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt5985288',
#    'download': '0'},
#   {'netflixid': '80227116',
#    'title': 'G&ouml;r&uuml;mce',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWnObpgUH2A3cRxiywCD5meW7H8zvO6EyHuXQbBCmuhlZBoE8TlJEfrl0lLYdeh2FVGv_ieFJKexQe_uIGMmIWp8Lw.jpg?r=f52',
#    'synopsis': 'When his jealous sister plots to wreck his engagement, a young man does everything he can to protect his betrothed from her devious schemes.<br><b>New on 2020-04-28</b>',
#    'rating': '5.1',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h44m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt6215910',
#    'download': '0'},
#   {'netflixid': '81254472',
#    'title': 'You Know Who',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABe1CwZMti7gXzf-yLoO4LiTWH85SePe4yCBUubz_CRODbgqbbmSZX2Vqog960-pgPN1IARu-M_yJvj9wFo0AULntIg.jpg?r=cef',
#    'synopsis': 'After a botched escape attempt, a fugitive convict&#39;s brain is swapped with that of his prison warden with comically awkward results.<br><b>New on 2020-04-28</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2003',
#    'runtime': '1h52m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81110387',
#    'title': 'R.K.Nagar',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWA-UY5o8W4WvgnhIgIt3td-jUd0PmLbU427uiOi6Grnw8CBntUZm5p2zmapSQp2BG7FLGFkqm_UWdsZW5yYjgmJRg.jpg?r=3ae',
#    'synopsis': 'Things look up for a Chennai man struggling to make ends meet when he falls for a politician&rsquo;s daughter -- until he gets entangled in a murder case.<br><b>New on 2020-04-28</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '2h12m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81207271',
#    'title': 'The Reliant',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABd_SB5PCcLiJvcBnTYMfA9pRI-61zpjInpdolHHHixiNThFH0rnygASqzDLZb5w2Sn6EoIJX8bkOhlz3i4gIweNBiQ.jpg?r=5ca',
#    'synopsis': 'When a town suffers an economic collapse, social unrest forces a family to seek refuge in the wilderness as bitter outlaws threaten their survival.<br><b>New on 2020-04-28</b>',
#    'rating': '4',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h56m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt6105774',
#    'download': '0'},
#   {'netflixid': '80038443',
#    'title': 'Organize Isler',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWku8E6QlgUk1gswFHRgtLzRDh896CRbbj-AEPKJ0gDG18b-MKL4CR_ozeUy8gc6CCWZ33U67XEajKDnFCX0IEgCRw.jpg?r=e47',
#    'synopsis': 'A gang leader recruits a suicidal Superman impersonator, while a woman driving a hot car linked to the gang plots revenge against them and their hero.<br><b>New on 2020-04-28</b>',
#    'rating': '7.4',
#    'type': 'movie',
#    'released': '2005',
#    'runtime': '1h44m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt0470883',
#    'download': '0'},
#   {'netflixid': '80134525',
#    'title': 'Neseli Hayat',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQjD0BZduRgwBHuliGwfT8LwomiefHhKPsPhc7-MdNuujvSyJKmEPu28dAmVc10b0zm_tIUWkaTFCM6TTAQk1jnLdA.jpg?r=ca3',
#    'synopsis': 'Burdened by troubles and caught between cultures, Riza takes a job as a mall Santa and finds that real life may not be so different from make believe.<br><b>New on 2020-04-28</b>',
#    'rating': '6.1',
#    'type': 'movie',
#    'released': '2009',
#    'runtime': '1h47m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt1523515',
#    'download': '0'},
#   {'netflixid': '80227117',
#    'title': '&#x130;stanbul K&#x131;rm&#x131;z&#x131;s&#x131;',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZYV9ZGmr7Rf_brrxxGXIPa2zSa8OLOoPngbqdtBuFjqQL85MGmpxKWt6JLN21y7IDb-AOrgqrcNPGRQjdckhah71Q.jpg?r=506',
#    'synopsis': 'Upon his return to Istanbul, an expat writer-editor finds himself stranded inside a web of tangled relationships after his filmmaker friend vanishes.<br><b>New on 2020-04-28</b>',
#    'rating': '5.5',
#    'type': 'movie',
#    'released': '2017',
#    'runtime': '1h49m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt5927352',
#    'download': '0'},
#   {'netflixid': '80227114',
#    'title': 'K&uuml;&ccedil;&uuml;k Esnaf',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABVLxcMt0ZgcfkGvvhPz9sy6Ls4qa-VizilZs31wHd5NOBh7XK2qqmXaR6U9ByyD8-VGTyszF9TGaUY9QTBXb_s84eA.jpg?r=693',
#    'synopsis': 'As an honest locksmith scrambles to pay his late father&#39;s hefty debt to the mafia, he crosses paths with a woman in similar trouble and falls for her.<br><b>New on 2020-04-28</b>',
#    'rating': '5.6',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h40m',
#    'largeimage': '',
#    'unogsdate': '2020-04-28',
#    'imdbid': 'tt5535942',
#    'download': '0'},
#   {'netflixid': '80209024',
#    'title': 'A Secret Love',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABV1TWwpVQiuIiAvYwR0a0y67wnxOiyIkY45lqwz_ckVx6IhU7m3l5I4cmwWF03p-4eTIgxpHLekcIVEGDBm6WjYxxWFq3s61hSCD79ny6NKwV78j6diUVmg4-Os.jpg?r=f1e',
#    'synopsis': 'Amid shifting times, two women kept their decades-long love a secret. But coming out later in life comes with its own set of challenges.<br><b>New on 2020-04-29</b>',
#    'rating': '0',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h22m',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': 'tt3260524',
#    'download': '0'},
#   {'netflixid': '81074065',
#    'title': 'Murder to Mercy: The Cyntoia Brown Story',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABTnTHQqPaKhwdup5T453BI3FBegRFAmfH3_j0o78XnKlJLYw6-r1LG-wwXeNlHyLBJ3c6d9PLsW34aGDPk50aLzYjXz3I36-eBp4A22tdCsGREhZViyWKa_I3cY.jpg?r=361',
#    'synopsis': 'After 16-year-old Cyntoia Brown is sentenced to life in prison, questions about her past, physiology and the law itself call her guilt into question.<br><b>New on 2020-04-29</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h37m',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80990668',
#    'title': 'Extracurricular',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABRNWwktdJxeEvfjWK4vfPaMpBKowOeAPwNikfH2DKsfQXZlbEjEc2flzdZ5DIsKFE_M5oRHPfRmfwqJIkU9iSGcDUX_pDV0OwJ31RDEa-nSL1gIuOo_WlNZPZuI.jpg?r=3d9',
#    'synopsis': 'A model high school student who&#39;s steeped in a world of serious crime finds his double life upended when a classmate takes an interest in his secret.<br><b>New on 2020-04-29</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': 'tt10262630',
#    'download': '0'},
#   {'netflixid': '81185359',
#    'title': 'Nadiya&rsquo;s Time to Eat',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUSxdqNOxEw-7zZCQG7IilcDaVWQtpuvq1cmhQR3-NID3nq7i-ngvc3t7WnFKUkGloVJFk-P75FGLl412mSR_GM3XUPUENZ3fy82XXDDCQNXx1MJhH-E_dfF6tc.jpg?r=83e',
#    'synopsis': 'On this cooking show, Nadiya Hussain serves up delicious shortcuts, vital ingredients and fast favorites &mdash; perfect for today&#39;s time-strapped families.<br><b>New on 2020-04-29</b>',
#    'rating': '',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81004936',
#    'title': 'Summertime',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfXemXhkTcUpbIiIPO79q3LjnbA7YHupd0_FmRbk-9T4xlqWdigXobX07tGlJ1em0iprRZJBZ92qqGvSFhc98lztIQPwFk8VskVatF25Y-1DwUeQl1UpHK5kRTo.jpg?r=ce7',
#    'synopsis': 'Two young adults from very different backgrounds fall in love during a summer on Italy&rsquo;s Adriatic Coast. Inspired by Federico Moccia&#39;s book series.<br><b>New on 2020-04-29</b>',
#    'rating': '7.1',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': 'tt11394340',
#    'download': '0'},
#   {'netflixid': '81270671',
#    'title': 'Love Is War',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfraf92xSL5cL-lAqN9o5K6DYe6-LFxVoYkSS01eFZNXO2qtpSAB-RcULUbqr9x4Rzo-r7tioE5H4nF6u8mrEYDe0A.jpg?r=983',
#    'synopsis': 'An adoring couple elects to test the strength of their marriage when they run against each other for the office of state governor.<br><b>New on 2020-04-29</b>',
#    'rating': '0',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h51m',
#    'largeimage': '',
#    'unogsdate': '2020-04-29',
#    'imdbid': 'tt10799940',
#    'download': '0'},
#   {'netflixid': '81045557',
#    'title': 'Dangerous Lies',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABY9fXCVfH8we32Ix6BhE9RiU2c6EL8T3qRrfbP9GKtWbYGwCBrb0QuKbHEhRm6RsOipLNJB3mxRr78BF67cSnKY1Nh5PduIFc-FqsJjaxu3tsGf7mgLVxX6buRg.jpg?r=bf0',
#    'synopsis': 'A broke caregiver unexpectedly inherits her patient&#39;s estate, but dark secrets swirl around her newfound wealth, tangling her in deceit and danger.<br><b>New on 2020-04-30</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h37m',
#    'largeimage': '',
#    'unogsdate': '2020-04-30',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81047512',
#    'title': 'Rich in Love',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcAk0hSJIodj2G2YDpKVWfgsMxkqPbmpAVZ5f-d0KIR6dPAMQOqAhWqevz8-5zHboBiMOeO2ZnehGxtiafIbxZ16_kF0CYhKSalZbn_Arw9juLNR-Xq14g4Gat0.jpg?r=b39',
#    'synopsis': 'Rich kid Teto is determined to prove himself to Paula, his love interest. But when he tells her he grew up poor, the lie spins out of control.<br><b>New on 2020-04-30</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h45m',
#    'largeimage': '',
#    'unogsdate': '2020-04-30',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80992788',
#    'title': 'DRIFTING DRAGONS',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbgeVfx-UmBuYO-gtOD0chgzDCJw19ZRBATxih4qJ9pXS2u9lF8ocGIsl063rPrRgV2FDlFOuEc3x3MqrTHPDLPtGg-yKgy9sG9LjVBMjChwSSy_LuEltu4h4_Y.jpg?r=73a',
#    'synopsis': 'Dragons are on the menu as the crew of the airship Quin Zaza sets out on a hunt. If they fail, empty stomachs will be the least of their worries.<br><b>New on 2020-04-30</b>',
#    'rating': '6.8',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-30',
#    'imdbid': 'tt11418344',
#    'download': '0'},
#   {'netflixid': '81227121',
#    'title': 'The Victims&#39; Game',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfwgNSKWlQTbskl-AO1AR8THzPiuj3daQ_6Vvc_bNocUI3rVluoqj42lC9Wue4xkL5FR1LfhfzO-AR1czGFO0i-M84v2Xf_GavRjJyaAJJY3V0zo2ms655GguIc.jpg?r=a7c',
#    'synopsis': 'After discovering his estranged daughter&#39;s link to mysterious murders, a forensic detective with Asperger&#39;s syndrome risks everything to solve the case.<br><b>New on 2020-04-30</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-30',
#    'imdbid': 'tt12079212',
#    'download': '0'},
#   {'netflixid': '80233251',
#    'title': 'The Forest of Love: Deep Cut',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQ6jZ_ChL_-Q-iMMHIm2XaqTKB-XChnST_kcFG2ueuknvjlTo3LnbKmODNK4iiPtghV06Tuhon19L89dyXibibmhyRa4NOubANbwholz4gfPfqvkceCqS0uu7K0.jpg?r=118',
#    'synopsis': 'Nothing&#39;s as it seems when a charismatic conman and an aspiring film crew delve into the lives of two emotionally scarred women.<br><b>New on 2020-04-30</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-04-30',
#    'imdbid': 'tt12079236',
#    'download': '0'},
#   {'netflixid': '215309',
#    'title': 'Ace Ventura: Pet Detective',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABR5C8rHk6ick0AtE2EbqL0KwLmy5hhdkDy6-wsNjDMh3ez5QvKcVIbgFlyNytcXUs4flgevCKbegxCvEq7Ai3K0Kxg.jpg?r=c6d',
#    'synopsis': 'Barely competent pet private eye Ace Ventura is put on the case when kidnappers with an ax to grind abduct Snowflake, the Miami Dolphins&#39; mascot.<br><b>New on 2020-05-02</b>',
#    'rating': '6.9',
#    'type': 'movie',
#    'released': '1994',
#    'runtime': '1h25m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0109040',
#    'download': '1'},
#   {'netflixid': '60026187',
#    'title': 'Above the Rim',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUf-YpWtjdmPCq-OaYsVCSBL5N25OJ-rEsOAZSiJCXotqXrBSzeKTLTyent4iES3y3gspkXawJav-XTm7qlT9tuHqA.jpg?r=053',
#    'synopsis': 'While Kyle awaits word from Georgetown about his basketball scholarship, he balances relationships with gangster Birdie and former pro baller Shep.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '1994',
#    'runtime': '1h37m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80226923',
#    'title': 'All Day and a Night',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABV4SR4gEDp9NLYuxC_HHbPljSspKkp3vLkS0L3ZGJHU3JSj4d_7mQ9kn6CfLI1pzatixsazzPBRlHzztw11bmtA76yd7ESXVIhKHfHmB9MMSMv-R6ys_1lBUVq8.jpg?r=950',
#    'synopsis': 'While serving life in prison, a young man looks back at the people, the circumstances and the system that set him on the path toward his crime.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '2h1m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt3993886',
#    'download': '0'},
#   {'netflixid': '80198592',
#    'title': 'Armed Response',
#    'image': 'https://occ-0-2773-2774.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbNDHDgIHz-GU5gPdyMj0F5v0UXclKxtRtS_-75XjktbhTbufEjwBdDO7I33sC1zWb68ZjSF7JmRESil_vR0Rk81fQ.jpg?r=e7b',
#    'synopsis': 'When a military compound run by a mind-reading artificial intelligence goes offline, a special-ops leader recruits his old team to investigate.<br><b>New on 2020-05-02</b>',
#    'rating': '3.7',
#    'type': 'movie',
#    'released': '2017',
#    'runtime': '1h33m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt4557208',
#    'download': '0'},
#   {'netflixid': '60010110',
#    'title': 'Back to the Future',
#    'image': 'https://occ-0-1348-1347.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABX8AN_0v-MMCns2Mg6EybmvhBXp-XQuC064tHHvwYM2mAW8I4NRFEL1XHKnXH1noz3pWDAajwxEIIY3n9suHnFJlXw.jpg?r=db2',
#    'synopsis': 'Eccentric inventor Doc Brown turns a DeLorean into a time machine that inadvertently sends his young friend, Marty McFly, 30 years into the past.<br><b>New on 2020-05-02</b>',
#    'rating': '8.5',
#    'type': 'movie',
#    'released': '1985',
#    'runtime': '1h56m',
#    'largeimage': 'http://cdn0.nflximg.net/images/2754/9642754.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0088763',
#    'download': '1'},
#   {'netflixid': '60010111',
#    'title': 'Back to the Future Part II',
#    'image': 'https://occ-0-114-116.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdbXFAwTl7GqJJrdnB3nxnmE6pul_UtBb9taM7oD65aq0Vp1qzemVu_riHoF3KXOkx5LCBeYO9rOzFva1K-sPRt25Q.jpg?r=ed6',
#    'synopsis': 'Marty and Doc are at it again in this sequel to the 1985 blockbuster as the time-traveling duo head to 2015 to nip some McFly family woes in the bud.<br><b>New on 2020-05-02</b>',
#    'rating': '7.8',
#    'type': 'movie',
#    'released': '1989',
#    'runtime': '1h48m',
#    'largeimage': 'http://cdn0.nflximg.net/images/0993/8360993.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0096874',
#    'download': '1'},
#   {'netflixid': '81173115',
#    'title': 'Bennett&#39;s War',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABS3w2_o4GVnG5BVhtHP1ROP6xxIviC-EwR-bjDNYKxZ7_jAOurMSbtOhrWA5_c6bPuua6NTlwCFrXKWIKFyFEusLwA.jpg?r=b62',
#    'synopsis': 'A medically discharged soldier attempts an improbable return to motorcycle racing to win enough prize money to save his father&#39;s farm.<br><b>New on 2020-05-02</b>',
#    'rating': '5.2',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h34m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt7370952',
#    'download': '0'},
#   {'netflixid': '70267802',
#    'title': 'Blackfish',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABeVc7Jtv2_BNxFZQUErRDY6WDto06E3RfC4rXSSyGsBsIKd8yCL0b-cJJyduB31fyI5lpygaB1Pl5kbX1pzxkUiQ5A.jpg?r=fbb',
#    'synopsis': 'This fascinating documentary examines the life of performing killer whale Tilikum, who has caused the deaths of several people while in captivity.<br><b>New on 2020-05-02</b>',
#    'rating': '8.1',
#    'type': 'movie',
#    'released': '2013',
#    'runtime': '1h23m',
#    'largeimage': 'http://cdn1.nflximg.net/images/6565/8886565.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt2545118',
#    'download': '1'},
#   {'netflixid': '70021648',
#    'title': 'Charlie and the Chocolate Factory',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABRgPfot73BtrpYKqwOC45h1HbwHryJzeQdvZ0_AtZtIIA-ZQtrMsCD-p5TldzM-Vyhlk7Ce11Q4_1c3F1dl6v9BWNw.jpg?r=376',
#    'synopsis': 'Charlie is one of five golden-ticket holders treated to a tour of Willy Wonka&#39;s chocolate factory in Tim Burton&#39;s take on the children&#39;s classic.<br><b>New on 2020-05-02</b>',
#    'rating': '6.6',
#    'type': 'movie',
#    'released': '2005',
#    'runtime': '1h55m',
#    'largeimage': 'http://cdn1.nflximg.net/images/8219/8488219.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0367594',
#    'download': '1'},
#   {'netflixid': '70100380',
#    'title': 'The Curious Case of Benjamin Button',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUElygQ1ONUn_2sLa8r3CVfxQxmZrFC_6zSBo6D9OaioZ4VQ1ZNBz6JokSgV0k86hCGNTEJWLzK7pGdS0AFNgdBQng.jpg?r=8dd',
#    'synopsis': 'David Fincher directs this Oscar-nominated tale of Benjamin Button, a man who was born old and wrinkled but grows younger as the years go by.<br><b>New on 2020-05-02</b>',
#    'rating': '7.8',
#    'type': 'movie',
#    'released': '2008',
#    'runtime': '2h46m',
#    'largeimage': 'http://cdn0.nflximg.net/images/0588/9090588.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0421715',
#    'download': '0'},
#   {'netflixid': '81162153',
#    'title': 'Cracked Up: The Darrell Hammond Story',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABTrWGnXyCLpSzSwEt96Nr0UnPzzmZEnfqSjwSYEzA6qB7I7CpgKBCSQR38DlxWZokTW0jzZ2S3rI-pudm8tNUTDMyw.jpg?r=7ee',
#    'synopsis': '&#39;Saturday Night Live&#39; star Darrell Hammond reveals the extreme abuse he suffered during childhood, a trauma that nearly destroyed his life as an adult.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2018',
#    'runtime': '1h37m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80196448',
#    'title': 'Den of Thieves',
#    'image': 'https://occ-0-2773-2774.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYY_C4p8MqDdo-Ps8NO1Y7BmWdjQdpTWIZ6ut9UNuYfJLToy1_vpAG5J6ieUTc7YFweZk-fTOi19qqbAicMCFMDGMw.jpg?r=283',
#    'synopsis': 'A highly skilled crew of bank robbers plotting a heist at the supposedly impenetrable Federal Reserve faces off against an elite unit of L.A. cops.<br><b>New on 2020-05-02</b>',
#    'rating': '7',
#    'type': 'movie',
#    'released': '2018',
#    'runtime': '2h20m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1259528',
#    'download': '0'},
#   {'netflixid': '81091382',
#    'title': 'Death Can Wait',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZil1AqQVsqWRR5m5M7dL_iAqfZZi9C2ppJ9lfjNMKY2pj_F0aj_71WKSrx45Q8Qr4pwfXDcivYhfrZT9X9rO4ODVQ.jpg?r=05f',
#    'synopsis': 'After learning he may die soon, a modest accountant pulls off a shady money scheme and heads to Europe, where he&#39;s faced with a life-or-death situation.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h30m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70141655',
#    'title': 'For Colored Girls',
#    'image': 'http://art-2.nflximg.net/8f743/fdc5e7ee0c40d028fde54fac9bcd2e3e54e8f743.jpg',
#    'synopsis': 'This adaptation of Ntozake Shange&#39;s play consists of a series of poetic vignettes that explore the lives of modern African American women.<br><b>New on 2020-05-02</b>',
#    'rating': '6',
#    'type': 'movie',
#    'released': '2010',
#    'runtime': '2h13m',
#    'largeimage': 'http://cdn1.nflximg.net/images/7991/11727991.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1405500',
#    'download': '1'},
#   {'netflixid': '60004107',
#    'title': 'Get on the Bus',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABY6dQ0voUKfOIAlXFXIDW5r-eBA4X3Cv_6EEERKC-AC9OJH1B19vngbkEip9qdj3Vq24HtkAFHExQlLjNo2mOHZ8zw.jpg?r=024',
#    'synopsis': 'A diverse group of African-American men treks from LA to Washington, DC in an eventful cross-country journey to the Million Man March.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '1996',
#    'runtime': '2h1m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70021643',
#    'title': 'Fun with Dick and Jane',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfrTlCq_otSIpWggrRjAYJip_lr-3aQs2AwZbYtgBhnx5O0UFtANNsZhduPZzVD8Sj2yTGxKevnS0fMto41a569jsQ.jpg?r=b97',
#    'synopsis': 'After losing their high-paying corporate jobs, an upwardly mobile couple turns to robbing banks to maintain their standard of living.<br><b>New on 2020-05-02</b>',
#    'rating': '6.1',
#    'type': 'movie',
#    'released': '2005',
#    'runtime': '1h30m',
#    'largeimage': 'http://cdn0.nflximg.net/images/0470/8470470.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0369441',
#    'download': '1'},
#   {'netflixid': '81158163',
#    'title': 'Get In',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfNoFuWr1r4AD43ETWWwwBxFcmFvQ7OjBLDLEc_YgkzonT5K-66ku9LWFwJPARZ-5sTiSKKBVtVL4K_rs1ddl5UoYyR0CTzHni7Z5nmzlaj3eI8K13getexAa-k.jpg?r=255',
#    'synopsis': 'When he returns from vacation and finds his home occupied by squatters, a family man is caught in a conflict that escalates to terrifying heights.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h38m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81005150',
#    'title': 'The Half Of It',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQr6IOvWKpzV7fJ-VWCsjuhjCdeOtAxcHTbcNEFCztLZe-fsRvXgH38GSqT41oRD6N3MCN1hNcrB0rJFFV_C9TJm4bvW2xPdgpetZs_KuSNL4CxCnBpD1X-UEhw.jpg?r=681',
#    'synopsis': 'When smart but cash-strapped teen Ellie Chu agrees to write a love letter for a jock, she doesn&#39;t expect to become his friend &mdash; or fall for his crush.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h45m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt9683478',
#    'download': '0'},
#   {'netflixid': '70060003',
#    'title': 'The Heartbreak Kid',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbwY4Q3-2vaez1Gfr7BDFXi8og1NYnVipJUSg8rIwBi8WtGjN9EU1U1DQ0W91wuMpd18vTCOHK9vZ9P7Ktl07vvBVQ.jpg?r=3ce',
#    'synopsis': 'Ben Stiller stars as a newlywed who marries a dreamy woman, only to learn on their honeymoon that she&#39;s a total nightmare.<br><b>New on 2020-05-02</b>',
#    'rating': '5.8',
#    'type': 'movie',
#    'released': '2007',
#    'runtime': '1h55m',
#    'largeimage': 'http://cdn1.nflximg.net/images/7747/23727747.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0408839',
#    'download': '0'},
#   {'netflixid': '81259883',
#    'title': 'Har Kisse Ke Hisse: Kaamyaab',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABerxl3j5kCS6s6cfpKr37m2Cmn5h1CU94FixL1v-L2tbSp7z66PHgMJYXSL6GIthdnaegRrQvvUrEUS2b2_E_2Nkpg.jpg?r=c97',
#    'synopsis': 'After a career of thankless credits, a retired actor returns for a long-awaited leading role but finds he is utterly unprepared for new-age filmmaking.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h44m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70273272',
#    'title': 'I Am Divine',
#    'image': 'https://occ-0-299-300.1.nflxso.net/art/db5f0/2d818c19fdf7afd2eba26b0823cb288e583db5f0.jpg',
#    'synopsis': 'This captivating documentary explores the life and work of filmmaker John Waters&#39;s muse: internationally celebrated drag superstar Divine.<br><b>New on 2020-05-02</b>',
#    'rating': '7.6',
#    'type': 'movie',
#    'released': '2013',
#    'runtime': '1h30m',
#    'largeimage': 'http://cdn0.nflximg.net/images/4540/9744540.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1356790',
#    'download': '1'},
#   {'netflixid': '60020949',
#    'title': 'Willy Wonka and the Chocolate Factory',
#    'image': 'https://occ-0-784-778.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZ9uS9MQi9ItFXh07Tmnjancq5-PTHKi-VDlWaVEHMQ7JqH-kRW8DmS0e_3_6F_fSKA7lKsNacQ_YVeNgK2Aky70-w.jpg?r=82e',
#    'synopsis': 'Zany Willy Wonka causes a stir when he announces that golden tickets hidden inside his candy bars will admit holders into his secret confectionary.<br><b>New on 2020-05-02</b>',
#    'rating': '7.8',
#    'type': 'movie',
#    'released': '1971',
#    'runtime': '1h39m',
#    'largeimage': 'http://cdn1.nflximg.net/images/0449/9280449.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0067992',
#    'download': '0'},
#   {'netflixid': '60026155',
#    'title': 'What a Girl Wants',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUCGej9mGR2WqbOnQJbJIs7SH8gWk90VkZUVPEu5ZV9CalsE6RQCaBnclO3igo5WPHWaCd3LaR0cO3oHmirG83K5kg.jpg?r=f1f',
#    'synopsis': 'In search of the father she&#39;s never met, the daughter of a bohemian American woman heads to Europe and finds that her dad is an uptight politician.<br><b>New on 2020-05-02</b>',
#    'rating': '5.8',
#    'type': 'movie',
#    'released': '2003',
#    'runtime': '1h44m',
#    'largeimage': 'http://cdn1.nflximg.net/images/1511/8511511.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0286788',
#    'download': '0'},
#   {'netflixid': '60024038',
#    'title': 'Urban Cowboy',
#    'image': 'http://art-2.nflximg.net/7a714/2a7f97eec7d186d78747d87892209c16e497a714.jpg',
#    'synopsis': 'A Texas farm boy who moves to the city gravitates to a honky-tonk with a mechanical bull and fast women, including a sassy flirt he impetuously weds.<br><b>New on 2020-05-02</b>',
#    'rating': '6.2',
#    'type': 'movie',
#    'released': '1980',
#    'runtime': '2h14m',
#    'largeimage': 'http://cdn1.nflximg.net/images/4147/8154147.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0081696',
#    'download': '0'},
#   {'netflixid': '60031210',
#    'title': 'Underworld',
#    'image': 'https://occ-0-768-769.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABVIGpCtvTQU4uavS3EiRCAm47vkHf3RarOsDn8S3oMLgAIdfHBU-WZL6Rx1Erdw3M1rCV8mpBjNm0HyvukBqeQpJbQ.jpg?r=db9',
#    'synopsis': 'A vampire suspects that her mortal enemies, werewolves known as Lycans, are targeting a human. As she shadows him, she finds herself falling in love.<br><b>New on 2020-05-02</b>',
#    'rating': '7',
#    'type': 'movie',
#    'released': '2003',
#    'runtime': '2h1m',
#    'largeimage': 'http://cdn1.nflximg.net/images/9211/21869211.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0320691',
#    'download': '1'},
#   {'netflixid': '70042678',
#    'title': 'Underworld: Evolution',
#    'image': 'https://occ-0-114-116.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbEvNyv2DYPLjjRsAACOz8AGG4xRhrUEAyiRZgojlrvNSB2tXvpbxyvKKCef7fVTbINZfXeWqGQDmTPbwVSvL7AuXg.jpg?r=edf',
#    'synopsis': 'Vampire warrior Selene and werewolf hybrid Michael learn the history of the ongoing war between the patrician Death Dealers and the barbarous Lycans.<br><b>New on 2020-05-02</b>',
#    'rating': '6.7',
#    'type': 'movie',
#    'released': '2006',
#    'runtime': '1h46m',
#    'largeimage': 'http://cdn0.nflximg.net/images/5029/8575029.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0401855',
#    'download': '1'},
#   {'netflixid': '70101347',
#    'title': 'Underworld: Rise of the Lycans',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZCbIlrBG1ja49YIBu9UyJTpzJ8srOBtYElhoAIKM70DsJnI_mrduGITs4R61bBE04Z1gb52NxIirkdVem2IzJKMyg.jpg?r=45d',
#    'synopsis': 'Tracing the backstory of the long war between the ruling-class vampires and the enslaved Lycans, this bloody prequel depicts the feud&#39;s first dustups.<br><b>New on 2020-05-02</b>',
#    'rating': '6.6',
#    'type': 'movie',
#    'released': '2009',
#    'runtime': '1h32m',
#    'largeimage': 'http://cdn0.nflximg.net/images/6889/8996889.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0834001',
#    'download': '1'},
#   {'netflixid': '81021355',
#    'title': 'Go! Go! Cory Carson: The Chrissy',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABXIMo8ZJ2RdQ79OUTekTGHnWe3vNMyxKI3jrz8qoHz2rfWmhbA2hATWPD3Z70p7HPcxKKuL-PIjJoY7cz5Gl9VSrq6QMuHBrfjsBl9h-qGYYMaxGsUsgNZPixn4.jpg?r=6a9',
#    'synopsis': 'The Carson kids win a talent show with a dance that Cory created. But when &#39;The Chrissy&#39; catches on, his little sister gets all of the attention.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '42m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81260313',
#    'title': 'Thomas &amp; Friends: Marvelous Machinery: A New Arrival',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABReY5kAD2YfvMhz7u20BLjCGNzHGjmf1_3CRjV3yMwLhbx4RsbVkiw-FCI6Hju_cDO7RS5gqkmNYm2L-iUd-PQ7YiA.jpg?r=4ef',
#    'synopsis': 'With a technology fair in Sodor, Thomas and the Steam Team tackle a flurry of tasks &mdash; but can they complete their deliveries before the grand opening?<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '22m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81260314',
#    'title': 'Thomas &amp; Friends: Marvelous Machinery: World of Tomorrow',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfO28ZwHeV3oP5Xr94N6HUU_XE5cWHsNReYAqxYKYDS2SKjtYaL6t2knMckLuWIhtT66ZMLaMp1HHnGKY-duGU2ehg.jpg?r=5ff',
#    'synopsis': 'Amid special demonstrations in Sodor, Thomas and the gang worry they&#39;ll be replaced by new inventions until a mission shows how useful they really are.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '22m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81260315',
#    'title': 'Thomas &amp; Friends: Thomas and the Royal Engine',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQRvhZJyolo-kHJ2TqWE-E-0cQgRrok5g2fEQ3TsCFAEde882yDsY_1puBK8B0F3bBtV0yxGlD2sKwyHg2t6crbdJw.jpg?r=bff',
#    'synopsis': 'An invitation from the Queen sends Thomas and the crew to London as they weave through delays and debacles while racing to a royal celebration.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '23m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80015342',
#    'title': 'Song of the Sea',
#    'image': 'https://occ-0-3451-2794.1.nflxso.net/art/05c84/af9e296b31aecaef521e2f1b2b9399eef4705c84.jpg',
#    'synopsis': 'The last of a magical race of seals that become human on dry land, Saoirse and her brother must return to the sea in this animated adventure.<br><b>New on 2020-05-02</b>',
#    'rating': '8.1',
#    'type': 'movie',
#    'released': '2014',
#    'runtime': '1h33m',
#    'largeimage': 'http://cdn0.nflximg.net/images/6973/24786973.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1865505',
#    'download': '1'},
#   {'netflixid': '81271289',
#    'title': 'The Stand at Paxton County',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABd-4iCGKLqkzKkYcH15xpBvC02D_jUqysj-MveAjfmb9grooXz8mbqqpbkM_DLoOBE0kkkxpDE4YAgDupFRZQCI5KA.jpg?r=ff2',
#    'synopsis': 'A military veteran comes home to find her father harassed by a sheriff intent on confiscating the livestock on their ranch under shady pretenses.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h42m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70000110',
#    'title': 'She Hate Me',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQwRNsnfP-PVTvGXPRSnTKN1i3I97IFZ5zZMeJ_DyZjjMMwxJf-VRxuIxSp2KEK0qdlcM8HAkVEX3xfFRxVFZu_IlQ.jpg?r=cd9',
#    'synopsis': 'After exposing his bosses and getting fired, a biotech executive finds a more lucrative &mdash; and scandalous &mdash; business opportunity ... between the sheets.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2004',
#    'runtime': '2h18m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '70221486',
#    'title': 'Sinister',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABe_xe7rqd9_YVAVpaRvaaPDu4PG6F_-5du704lzld_7-xF2crCnvxl48SOurUEutS7dzPkGQqNUumohAvr0moSu-6w.jpg?r=adf',
#    'synopsis': 'A true-crime writer discovers a cache of videotapes depicting several brutal murders that took place in the very house he just bought.<br><b>New on 2020-05-02</b>',
#    'rating': '6.8',
#    'type': 'movie',
#    'released': '2012',
#    'runtime': '1h49m',
#    'largeimage': 'http://cdn0.nflximg.net/images/5046/11625046.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1922777',
#    'download': '1'},
#   {'netflixid': '81271288',
#    'title': 'Roped',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWIjVZWl5FVRt8mUE6n7IcMK56_R1VLsW0rEXNw8LHWp5on55rYQOmBKSWql-Hj_RTO3y_gGJm4ByjUdMWw5cmEZDQ.jpg?r=098',
#    'synopsis': 'A star cowboy in a traveling rodeo gets thrown off course when he falls in love with the daughter of a tough-minded town councilman.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h30m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '60000396',
#    'title': 'Romeo Must Die',
#    'image': 'https://occ-0-2851-38.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABe44fMwrOmgZRsIRJ_A-dek3CAu__eyxtJuuCyqHO8yeoKf93MUeOkkAUXbz8HgIof-ElIBONxsXBITYI6P8wgCW1g.jpg?r=c44',
#    'synopsis': 'Hang Sing, who has ties to the Chinese mafia, searches for his brother&#39;s killer and falls for Trish, whose father leads an African American gang.<br><b>New on 2020-05-02</b>',
#    'rating': '6.1',
#    'type': 'movie',
#    'released': '2000',
#    'runtime': '1h54m',
#    'largeimage': 'http://cdn0.nflximg.net/images/8918/9138918.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0165929',
#    'download': '0'},
#   {'netflixid': '81278143',
#    'title': 'Psycho',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYE5-RRaFmPGPEJP5YlZuz76htI-1CvF7p081XBPDZHIxYqWbF-6Ya26-o-N_i10p8SC3Dmf1U9GgBNVlzxzw_-Qhw.jpg?r=57b',
#    'synopsis': 'As a visually impaired man attempts to rescue his love interest from a serial killer, the dark story behind the murderer&rsquo;s disturbing psyche emerges.<br><b>New on 2020-05-02</b>',
#    'rating': '6.8',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '2h23m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt9109976',
#    'download': '0'},
#   {'netflixid': '60001044',
#    'title': 'The Patriot',
#    'image': 'https://occ-0-34-32.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWaM_cr6ktm23niMUAsvJPydcIYCkdc6R-rX471y0IsJzZZoa4rz26s914MYFZocjhWOvRFnfMo_WY_aG58q33FqPg.jpg?r=7df',
#    'synopsis': 'A widower and past war hero just wants to live in peace and farm his land -- until a cruel British officer brings the American Revolution to his door.<br><b>New on 2020-05-02</b>',
#    'rating': '7.2',
#    'type': 'movie',
#    'released': '2000',
#    'runtime': '2h45m',
#    'largeimage': 'http://cdn1.nflximg.net/images/0663/8170663.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0187393',
#    'download': '1'},
#   {'netflixid': '81076113',
#    'title': 'Mrs. Serial Killer',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABe5z9_tlqfbb_6I7pgJZsB9seyo_1velurf3CuDX8GFyvmPGgbn_lThUqU6mXfg6Sd8uMR5mRopU9oKeM5IjdOBumhi5urlxRAqcMMUQU7eFkK85Y-euWAsgweA.jpg?r=d6f',
#    'synopsis': 'When a doctor gets jailed for a string of shocking murders, his loyal wife sets out to commit a copycat crime to prove his innocence.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'movie',
#    'released': '2020',
#    'runtime': '1h46m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt10230426',
#    'download': '0'},
#   {'netflixid': '81260303',
#    'title': 'Material',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABac5oMHFre0A1QAI3SnQIvs-xxOvI5BU8LSACl8Umf5pwv3cYp0Xxy_SXQuJJuBC0SfJuCnMzSJ3VlJ2INC88b3Zww.jpg?r=3f2',
#    'synopsis': 'A dutiful son must hide his pursuit of stand-up comedy from his staunch father, who expects him to inherit his store and uphold their Muslim beliefs.<br><b>New on 2020-05-02</b>',
#    'rating': '7.7',
#    'type': 'movie',
#    'released': '2012',
#    'runtime': '1h34m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1899240',
#    'download': '0'},
#   {'netflixid': '80225954',
#    'title': 'Almost Happy',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcv5TgssuR7KtAjVceeLt01khr9tyRE9FN4CMLDdD1WzKsimK8jJDU5-f2UKv_AsgWG-FbBkCzt3dhGnelGNBw866fu8OotayPlVirLlSABAQZkGuxUOPQ4TIUM.jpg?r=8e2',
#    'synopsis': 'Sebasti&aacute;n is a radio show host of modest fame, trying to find a way in the world as he deals with his ex-wife (whom he still loves) and two kids.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt12146940',
#    'download': '0'},
#   {'netflixid': '81081459',
#    'title': '44Cats',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWZcbXNpu1ooHLa-whgYBxFH09M_2b9XqAkonrY9F9g2HDPgBghhj01x5Z4gtdR0w2y0m0KDI_Za1f0UZP4tdFpnBw.jpg?r=71f',
#    'synopsis': 'Paw-esome tales abound when singing furry friends Lampo, Milady, Pilou and Meatball band together.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2018',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt9699148',
#    'download': '0'},
#   {'netflixid': '70157400',
#    'title': 'Hoarders',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABcPVMX0dSPxCu-D0bREc7AozvGazs11J5l1x91CPe4-LTVEgoOITJBYGwGWEr9bmZgSwW_0uZhaSSEMe8cdAWNN3Cw.jpg?r=c14',
#    'synopsis': 'This reality series enters the worlds of compulsive hoarders, whose addiction to acquisition overwhelms not just their homes but also their lives.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'show',
#    'released': '2019',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81088617',
#    'title': 'Hollywood',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYWhvrC-3DkwOcjG3x0lDfDPLB9QEG7keQkJZh9WfInwaVqNfMRv9XRv1EluB6itQJZATARKMEtR1-fcIxAAPILCiPWari4PJOxlSXf-5hTvfcHQsrEF_sUOnek.jpg?r=419',
#    'synopsis': 'In post-World War II Hollywood, an ambitious group of aspiring actors and filmmakers will do almost anything to make their showbiz dreams come true.<br><b>New on 2020-05-02</b>',
#    'rating': '5.5',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt9827854',
#    'download': '0'},
#   {'netflixid': '81271145',
#    'title': 'Hangar 1: The UFO Files',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/9pS1daC2n6UGc3dUogvWIPMR_OU/AAAABRethFBdx7gAIiUOgy_Gjy0VVmqpsCaL7Hgvr64VL-B8XZ8dzf2y6737SfhbfhBJSYccFbHjBSFe4cjZb6f3Kv30BdasBEYxdGWAahssFwirPQ.jpg?r=4e6',
#    'synopsis': 'Researchers add context and clarity to UFO mysteries and conspiracy theories as they unpack clues in a trove of files covering decades of sightings.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'show',
#    'released': '2014',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81008221',
#    'title': 'Into the Night',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYokJrs_hzPn7VCSs_OvoSwnaAZEFxfD4vliE6uqclaU2v3g8hB5liLqZ2KOTCQAoAj-NYlgHrh41aFNudhnm4dQXjTrBf2pkWDPunaOccHNfpotckVoWVJICYc.jpg?r=320',
#    'synopsis': 'Passengers and crew aboard a hijacked overnight flight scramble to outrace the sun as a mysterious cosmic event wreaks havoc on the world below.<br><b>New on 2020-05-02</b>',
#    'rating': '0',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt10919486',
#    'download': '0'},
#   {'netflixid': '80081848',
#    'title': 'Monthly Girls&#39; Nozaki Kun',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABRLgWzJK4Fsh10zxMuIF8Eo1Z978NbX6vA2N0umAEuZr9Iw5nfaP82nQ-z1KvWXS1kd9eD45sqbKAeSLgGHlQ7US7g.jpg?r=810',
#    'synopsis': 'Art imitates life when Chiyo discovers her crush is a famous artist who wants to use their budding relationship as inspiration for his romantic manga.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'series',
#    'released': '2014',
#    'runtime': '',
#    'largeimage': 'http://cdn1.nflximg.net/images/2739/23672739.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'notfound',
#    'download': '1'},
#   {'netflixid': '81275451',
#    'title': 'Oh Yuck',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZYxFAUnfEsHGYvJFJwKDLvpDrkFvSi3fGQNpPtPBcajMSn4c_W2v0KWFm6zTFa2wCYMoLoY1pf-3hPWwFqKdq2BOw.jpg?r=857',
#    'synopsis': 'Using a concoction of cartoons, comedy and live action, Dr. Yuck and his eccentric lab mates investigate the science behind the planet&#39;s ickiest things.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81196539',
#    'title': 'Polly Pocket',
#    'image': 'https://occ-0-114-116.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABUT93JZVyL8U57ZPr3yctW84Tr9fNNiNrXoa73_Pgp1Fb08zSZrbFuTKsBKvgXSksDSWfA2h9RON0XeIyOgtpw5yHw.jpg?r=5ef',
#    'synopsis': 'After uncovering a magical locket that allows her to shrink in size, Polly and her friends set out on big adventures with petite power.<br><b>New on 2020-05-02</b>',
#    'rating': '6.6',
#    'type': 'series',
#    'released': '2018',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt8673042',
#    'download': '0'},
#   {'netflixid': '81040639',
#    'title': 'Pup Academy',
#    'image': 'https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQBo7Z65OHSru3vjJ2iJwuf7hgwrHkL62MAWB5gTHs-fVbaol2v7lTsEJ7plOgiIhowJHqMWiakhSb4QjUebQ2dv1ZnNAsgSsTivlWmXzX-A1Rxd-kvACD98OMw.jpg?r=3de',
#    'synopsis': 'Furry friends take a re-bark-able journey in this series about an extraordinary school for the cutest, cuddliest and most curious puppies.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'series',
#    'released': '2020',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '81277909',
#    'title': 'Reckoning',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABf7oABNUq69L9qm78sspNc_HqJQbqVwHcsXgDUW3rgCMuCW3wgdhKI-appJ7SXPg0zBQKaHX3XD9KurakTr3iFhLbg.jpg?r=edb',
#    'synopsis': 'When a local teen is murdered in their quiet, suburban community, two fathers intent on protecting their families must contend with their inner demons.<br><b>New on 2020-05-02</b>',
#    'rating': '6.7',
#    'type': 'series',
#    'released': '2019',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt8690440',
#    'download': '0'},
#   {'netflixid': '70212566',
#    'title': 'WWII: Lost Films',
#    'image': 'http://cdn0.nflximg.net/images/2088/11922088.jpg',
#    'synopsis': 'Rare color footage interwoven with firsthand interviews and diary entries bring to life the global sweep of World War II via those who were there.<br><b>New on 2020-05-02</b>',
#    'rating': '8.7',
#    'type': 'series',
#    'released': '2009',
#    'runtime': '',
#    'largeimage': 'http://cdn0.nflximg.net/images/2092/11922092.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt1489097',
#    'download': ''},
#   {'netflixid': '81271182',
#    'title': 'The Universe: Ancient Mysteries Solved',
#    'image': 'https://occ-0-2218-2219.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABc-jfNwuvlWcgp4Gei3fJP94hnG7ivgktyS9tCELFiWMOMfFjWx9Cgbu8J8GyCfOoUtEFTAv27bK6IuILpFHidHmCA.jpg?r=9b2',
#    'synopsis': 'From astronomical events to shapes and patterns in space, strange and wonderful phenomena are explored with modern science in this series.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'show',
#    'released': '2015',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'},
#   {'netflixid': '80005495',
#    'title': 'Jarhead 2: Field of Fire',
#    'image': 'http://occ-1-2218-2219.1.nflxso.net/art/ebeaf/eef8db0a0e1d5af631471484348fae1dd2aebeaf.jpg',
#    'synopsis': 'A Marine contingent stationed in Afghanistan faces a daunting mission when they attempt to help a famously defiant woman escape the Taliban.<br><b>New on 2020-05-02</b>',
#    'rating': '5.4',
#    'type': 'movie',
#    'released': '2014',
#    'runtime': '1h42m',
#    'largeimage': 'http://cdn0.nflximg.net/images/2410/11922410.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt3699508',
#    'download': '1'},
#   {'netflixid': '80091138',
#    'title': 'Jarhead 3: The Siege',
#    'image': 'http://occ-0-3451-3446.1.nflxso.net/dnm/api/v6/XsrytRUxks8BtTRf9HNlZkW2tvY/AAAABWPOGmp8179KeI5_9vITTl6mlyHvm5Yt3ZCD5ki8-wDoVdvGYp_c9zuTMPah2euYpCDmWhNjlZKnbAoZJMxA0Td8WTOZXLM.jpg?r=d5a',
#    'synopsis': 'When insurgents assault a U.S. embassy, unsuspecting Marines guarding the compound are swept into a ferocious battle to protect civilian lives.<br><b>New on 2020-05-02</b>',
#    'rating': '5.2',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h28m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt4616014',
#    'download': '1'},
#   {'netflixid': '70099116',
#    'title': 'Madagascar: Escape 2 Africa',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABR14aWpaxXHT23A4zKtcdITsiAFiFv5IsEunP8-CnKk7m5cSIuU6-GkW8basRT4AJF2oUMfoMlsJuV-_tp-2-hmfIw.jpg?r=e9a',
#    'synopsis': 'A botched rescue strands Alex the lion and his companions in Africa. Sadly, Alex discovers he has little in common with the locals.<br><b>New on 2020-05-02</b>',
#    'rating': '6.6',
#    'type': 'movie',
#    'released': '2008',
#    'runtime': '1h29m',
#    'largeimage': 'http://cdn0.nflximg.net/images/7120/24367120.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0479952',
#    'download': '0'},
#   {'netflixid': '70021659',
#    'title': 'Jarhead',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQSJUiBb5oBV9AIwA3vE55wQZUVi_8Y704CZgJKgk9gI2TaOI4NJXOWJ0zOeesjqyfhXAYG5DoUX6Cugprh0KUjYWg.jpg?r=c47',
#    'synopsis': 'Instead of combat, this film focuses on the long, lonely days spent at war, and the caustic humor soldiers employ to deal with unbearable conditions.<br><b>New on 2020-05-02</b>',
#    'rating': '7',
#    'type': 'movie',
#    'released': '2005',
#    'runtime': '2h2m',
#    'largeimage': 'http://cdn1.nflximg.net/images/1861/10861861.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0418763',
#    'download': '1'},
#   {'netflixid': '70279934',
#    'title': 'Mike Birbiglia: My Girlfriend&#39;s Boyfriend',
#    'image': 'http://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWJYmAL82ri0AbEZj4a0ILSbpR2kBfpor1qBGej3GJoVQNazOBSvIIRi81i2uVBojcGIKM63ZAWYphDOrSeMNCl4BQ.jpg?r=1f9',
#    'synopsis': 'On this painfully honest but hilarious journey, Birbiglia struggles to find reason in an area where it may be impossible to find: love.<br><b>New on 2020-05-02</b>',
#    'rating': '8',
#    'type': 'movie',
#    'released': '2013',
#    'runtime': '1h15m',
#    'largeimage': 'http://cdn0.nflximg.net/images/8885/11788885.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt2937390',
#    'download': '1'},
#   {'netflixid': '81271257',
#    'title': 'Lady Driver',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZr84Epsb5FYBfpFEcy1MS2sYvaJqA0-gfMxvOOyxXEwsu7aNZsihQSP3HMs-PCjjCp7VmR3dw8H3SAde9brzLIp0g.jpg?r=57d',
#    'synopsis': 'When a rebellious teen searches for her unknown roots, it leads her to the sport of dirt track racing and a discovery she didn&#39;t expect.<br><b>New on 2020-05-02</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h44m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': '',
#    'download': '0'}]}

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi"

querystring = {"q":"get:exp:US","t":"ns","st":"adv","p":"1"}

headers = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': "54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"COUNT":"13","ITEMS":[{"netflixid":"80117082","title":"Two Lovers and a Bear","image":"https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdhBcmzxvLZPg2JKkfa39DNBowvIwFttcQSehUhpkMGWGiH1S9XQeEwxyG6FNL4tOnPhAeIFPWEG7OTt9yjjvm64LA.jpg?r=341","synopsis":"A troubled couple living near the North Pole begins a perilous journey south in an attempt to find peace and vanquish ghosts from the past.<br><b>Expires on 2020-05-02</b>","rating":"6.1","type":"movie","released":"2016","runtime":"1h35m","largeimage":"","unogsdate":"2020-05-02","imdbid":"tt4412528","download":"0"},{"netflixid":"70143369","title":"John Carter","image":"https://occ-0-2042-299.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABW8XvIz0qaCPn5dD1odjY7BUl0qn2E3OQ1hPJHuGO_EOHbRKMMIiV6Cy5qdt0sak-qzJjWeU6rz3czHJz7da1Ylk1g.jpg?r=5b0","synopsis":"One minute, Civil War veteran John Carter is evading Apaches; the next, he&#39;s waking up on Mars, a once-fruitful planet that&#39;s devolved into chaos.<br><b>Expires on 2020-05-02</b>","rating":"6.6","type":"movie","released":"2012","runtime":"2h12m","largeimage":"http://cdn1.nflximg.net/images/7363/9057363.jpg","unogsdate":"2020-05-02","imdbid":"tt0401729","download":"0"},{"netflixid":"80087897","title":"4th Man Out","image":"https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQ0YjC8z4jfyDzpYSlH2YQuRrWkTu4NA-vigUxyJ6VN_drCiw1x7RW3OyzB-D6UVrFaDJQ2GaBhFxnUZNUjAscy6xQ.jpg?r=7a8","synopsis":"A young mechanic comes out to his extremely straight best friends. Once they get used to the idea, they&#39;re determined to help him find the right guy.<br><b>Expires on 2020-05-05</b>","rating":"6.7","type":"movie","released":"2015","runtime":"1h26m","largeimage":"","unogsdate":"2020-05-05","imdbid":"tt3978720","download":"1"},{"netflixid":"80100933","title":"Se&ntilde;orita polvora","image":"http://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYi2aVhGAk-TWUrrQlos_lqHDTovLHrxojiJPLDmuj-9vx7gXb0Q5kKY8dpkMlqOfJSTIQL01B1euuZFY99DryELOw.jpg?r=392","synopsis":"Wealthy, beautiful Valentina falls in love, only to realize that her man and her family are involved with one of Mexico&#39;s most powerful drug cartels.<br><b>Expires on 2020-05-05</b>","rating":"7.6","type":"series","released":"2015","runtime":"","largeimage":"","unogsdate":"2020-05-05","imdbid":"tt3986120","download":"1"},{"netflixid":"80108613","title":"LoveTrue","image":"http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABRXsWg47jWxtjF-XilsY59H8LkO2ennv1ua06lS9ptc8ucSqmrpNyq3GkcJu_3_5zb0ldH-H_DNjcDcWLYhY75MOcw.jpg?r=b34","synopsis":"In this blend of documentary and dramatization, circumstances test notions of love held by a young stripper, a single-dad surfer and a teen musician.<br><b>Expires on 2020-07-05</b>","rating":"6.6","type":"movie","released":"2016","runtime":"1h22m","largeimage":"","unogsdate":"2020-07-05","imdbid":"tt2638900","download":"0"},{"netflixid":"20258084","title":"Andaz Apna Apna","image":"https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABa52zf7lpjKKqJSltopDVbycfSUQGmBEJIKKkbpev1SrlKj282B1L1vJp3WG4brPdFkmvj4QySeJ4TLBm5cfFV1Biw.jpg?r=b45","synopsis":"Two young men -- Prem and Amar -- are broke and have no concrete plans for the future when they discover that a stunning heiress lives nearby. Both Prem and Amar make it their mission to charm the young lady into marriage.<br><b>Expires on 2020-07-05</b>","rating":"8.2","type":"movie","released":"1994","runtime":"","largeimage":"http://cdn0.nflximg.net/images/1432/9881432.jpg","unogsdate":"2020-07-05","imdbid":"tt0109117","download":"1"},{"netflixid":"70158421","title":"Action Replayy","image":"https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWnEdc3nRqrQccoEBKSRvUu2By-FsoOq5astgy54ghCRrtiaj3rOl21LSAXtmuK5YQ0h1bp_AOXvegsnMayOcaahEg.jpg?r=1b2","synopsis":"Vipul Amrutlal Shah directs this sci-fi rom-com that stars Akshay Kumar and Aishwarya Rai as  ...

# %%
expiring = response.json()
expiring
# Out:
# {'COUNT': '13',
#  'ITEMS': [{'netflixid': '80117082',
#    'title': 'Two Lovers and a Bear',
#    'image': 'https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdhBcmzxvLZPg2JKkfa39DNBowvIwFttcQSehUhpkMGWGiH1S9XQeEwxyG6FNL4tOnPhAeIFPWEG7OTt9yjjvm64LA.jpg?r=341',
#    'synopsis': 'A troubled couple living near the North Pole begins a perilous journey south in an attempt to find peace and vanquish ghosts from the past.<br><b>Expires on 2020-05-02</b>',
#    'rating': '6.1',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h35m',
#    'largeimage': '',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt4412528',
#    'download': '0'},
#   {'netflixid': '70143369',
#    'title': 'John Carter',
#    'image': 'https://occ-0-2042-299.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABW8XvIz0qaCPn5dD1odjY7BUl0qn2E3OQ1hPJHuGO_EOHbRKMMIiV6Cy5qdt0sak-qzJjWeU6rz3czHJz7da1Ylk1g.jpg?r=5b0',
#    'synopsis': 'One minute, Civil War veteran John Carter is evading Apaches; the next, he&#39;s waking up on Mars, a once-fruitful planet that&#39;s devolved into chaos.<br><b>Expires on 2020-05-02</b>',
#    'rating': '6.6',
#    'type': 'movie',
#    'released': '2012',
#    'runtime': '2h12m',
#    'largeimage': 'http://cdn1.nflximg.net/images/7363/9057363.jpg',
#    'unogsdate': '2020-05-02',
#    'imdbid': 'tt0401729',
#    'download': '0'},
#   {'netflixid': '80087897',
#    'title': '4th Man Out',
#    'image': 'https://occ-0-1926-41.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABQ0YjC8z4jfyDzpYSlH2YQuRrWkTu4NA-vigUxyJ6VN_drCiw1x7RW3OyzB-D6UVrFaDJQ2GaBhFxnUZNUjAscy6xQ.jpg?r=7a8',
#    'synopsis': 'A young mechanic comes out to his extremely straight best friends. Once they get used to the idea, they&#39;re determined to help him find the right guy.<br><b>Expires on 2020-05-05</b>',
#    'rating': '6.7',
#    'type': 'movie',
#    'released': '2015',
#    'runtime': '1h26m',
#    'largeimage': '',
#    'unogsdate': '2020-05-05',
#    'imdbid': 'tt3978720',
#    'download': '1'},
#   {'netflixid': '80100933',
#    'title': 'Se&ntilde;orita polvora',
#    'image': 'http://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYi2aVhGAk-TWUrrQlos_lqHDTovLHrxojiJPLDmuj-9vx7gXb0Q5kKY8dpkMlqOfJSTIQL01B1euuZFY99DryELOw.jpg?r=392',
#    'synopsis': 'Wealthy, beautiful Valentina falls in love, only to realize that her man and her family are involved with one of Mexico&#39;s most powerful drug cartels.<br><b>Expires on 2020-05-05</b>',
#    'rating': '7.6',
#    'type': 'series',
#    'released': '2015',
#    'runtime': '',
#    'largeimage': '',
#    'unogsdate': '2020-05-05',
#    'imdbid': 'tt3986120',
#    'download': '1'},
#   {'netflixid': '80108613',
#    'title': 'LoveTrue',
#    'image': 'http://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABRXsWg47jWxtjF-XilsY59H8LkO2ennv1ua06lS9ptc8ucSqmrpNyq3GkcJu_3_5zb0ldH-H_DNjcDcWLYhY75MOcw.jpg?r=b34',
#    'synopsis': 'In this blend of documentary and dramatization, circumstances test notions of love held by a young stripper, a single-dad surfer and a teen musician.<br><b>Expires on 2020-07-05</b>',
#    'rating': '6.6',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h22m',
#    'largeimage': '',
#    'unogsdate': '2020-07-05',
#    'imdbid': 'tt2638900',
#    'download': '0'},
#   {'netflixid': '20258084',
#    'title': 'Andaz Apna Apna',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABa52zf7lpjKKqJSltopDVbycfSUQGmBEJIKKkbpev1SrlKj282B1L1vJp3WG4brPdFkmvj4QySeJ4TLBm5cfFV1Biw.jpg?r=b45',
#    'synopsis': 'Two young men -- Prem and Amar -- are broke and have no concrete plans for the future when they discover that a stunning heiress lives nearby. Both Prem and Amar make it their mission to charm the young lady into marriage.<br><b>Expires on 2020-07-05</b>',
#    'rating': '8.2',
#    'type': 'movie',
#    'released': '1994',
#    'runtime': '',
#    'largeimage': 'http://cdn0.nflximg.net/images/1432/9881432.jpg',
#    'unogsdate': '2020-07-05',
#    'imdbid': 'tt0109117',
#    'download': '1'},
#   {'netflixid': '70158421',
#    'title': 'Action Replayy',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWnEdc3nRqrQccoEBKSRvUu2By-FsoOq5astgy54ghCRrtiaj3rOl21LSAXtmuK5YQ0h1bp_AOXvegsnMayOcaahEg.jpg?r=1b2',
#    'synopsis': 'Vipul Amrutlal Shah directs this sci-fi rom-com that stars Akshay Kumar and Aishwarya Rai as Kishen and Mala, a married couple who are so miserable, they inspire their son, Bunty, to go back in time and make his parents fall in love.<br><b>Expires on 2020-07-05</b>',
#    'rating': '4.2',
#    'type': 'movie',
#    'released': '2010',
#    'runtime': '2h9m',
#    'largeimage': 'http://cdn0.nflximg.net/images/1282/9881282.jpg',
#    'unogsdate': '2020-07-05',
#    'imdbid': 'tt1396208',
#    'download': ''},
#   {'netflixid': '80091267',
#    'title': 'Jalpari: The Desert Mermaid',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABVdY8Uq9cXIdlABCBnzrlpT41u-QXNrIqzUs96pg8GV58G-LyKQD7A6ZjF4gEZ_VMLXBsc7pAH_pI2KbLk3plL-B8Q.jpg?r=e39',
#    'synopsis': 'When they travel to their father&#39;s ancestral village, city kids expecting a natural paradise instead find a poor, dusty town that harbors secrets.<br><b>Expires on 2020-07-05</b>',
#    'rating': '7.2',
#    'type': 'movie',
#    'released': '2012',
#    'runtime': '1h34m',
#    'largeimage': 'http://cdn1.nflximg.net/images/7133/24427133.jpg',
#    'unogsdate': '2020-07-05',
#    'imdbid': 'tt2387495',
#    'download': '1'},
#   {'netflixid': '80221308',
#    'title': 'Desolation',
#    'image': 'https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABfKYxRElp-sxGuFj_TSkKgpxoakWHjHCwnM-v24SJ-tw6ZQZQ203JDiSnben0n0i75UJJ2c1feLBp8XxgKWw3UfBag.jpg?r=a65',
#    'synopsis': 'Along with her son and best friend, a grieving widow hikes into the woods to scatter her late husband&#39;s ashes, only to discover they&#39;re being stalked.<br><b>Expires on 2020-08-05</b>',
#    'rating': '4.5',
#    'type': 'movie',
#    'released': '2017',
#    'runtime': '1h16m',
#    'largeimage': '',
#    'unogsdate': '2020-08-05',
#    'imdbid': 'tt5047400',
#    'download': '0'},
#   {'netflixid': '80217133',
#    'title': 'Kaleidoscope',
#    'image': 'https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABc7XCQfbpzV6jc9475jUm9S6ooARPhYsoDzXHrTyXK6vv07MhFdK99eY7M2B2nGMVBiCK6hSR495TNdVejBTh6V20w.jpg?r=02a',
#    'synopsis': 'A quiet ex-con&#39;s tenuous grip on reality starts to slip when his manipulative mother brings out a part of him he hoped to leave behind.<br><b>Expires on 2020-08-05</b>',
#    'rating': '5.7',
#    'type': 'movie',
#    'released': '2016',
#    'runtime': '1h39m',
#    'largeimage': '',
#    'unogsdate': '2020-08-05',
#    'imdbid': 'tt5634088',
#    'download': '0'},
#   {'netflixid': '80236993',
#    'title': 'The Desert Bride',
#    'image': 'https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABWHorP1623rJ0aGKCYpPnZ1lHLAxKsbVwRjp7vTPgqXPJ6qIoAe4tu3zvRN_ZcLhw9pZgWnuzeDitoWHU26X1DhrKw.jpg?r=476',
#    'synopsis': 'While traveling across Argentina to a new job, a longtime maid encounters a salesman who opens her eyes to life&#39;s beauty and possibilities.<br><b>Expires on 2020-08-05</b>',
#    'rating': '6.5',
#    'type': 'movie',
#    'released': '2017',
#    'runtime': '1h17m',
#    'largeimage': '',
#    'unogsdate': '2020-08-05',
#    'imdbid': 'tt6147512',
#    'download': '0'},
#   {'netflixid': '80194289',
#    'title': 'Gabriel and the Mountain',
#    'image': 'https://occ-0-2219-2218.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABV_dMzK4HsS6Zb2-mPmbQAQbl9Yt9mskDroGgUvOR_1KMrWfykA5o9UeVnV1cfnx-3KHB1hYazApuoSYmcbM22z4cg.jpg?r=2b9',
#    'synopsis': 'In a drama based on a true story, Brazilian backpacker Gabriel Buchmann spends his gap year exploring Africa. Why does he die in the Malawi mountains?<br><b>Expires on 2020-09-05</b>',
#    'rating': '7',
#    'type': 'movie',
#    'released': '2017',
#    'runtime': '2h11m',
#    'largeimage': '',
#    'unogsdate': '2020-09-05',
#    'imdbid': 'tt6805354',
#    'download': '0'},
#   {'netflixid': '81153372',
#    'title': 'Westside vs. the World',
#    'image': 'https://occ-0-1091-300.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABbsBhchoZzkGz4zUrOQpGpfKOir771ohk2TFOPkuDoJdZzfw2JRuRdodl6pp3e_l3kvtc8X0I2f_d7ixxqFp4m9Ycg.jpg?r=6b6',
#    'synopsis': 'A look into the journey of influential strength coach Louie Simmons and the Westside Barbell gym he founded, evolving the sport of powerlifting.<br><b>Expires on 2020-09-05</b>',
#    'rating': '',
#    'type': 'movie',
#    'released': '2019',
#    'runtime': '1h36m',
#    'largeimage': '',
#    'unogsdate': '2020-09-05',
#    'imdbid': '',
#    'download': '0'}]}

# %%
form = input("Enter 'movie' or 'series': ")
selection = input("Enter 'new' or 'expiring': ")

if form == 'movie' and selection == 'new':
    #THIS IS WHERE I AM STUCK
# Out:
# Enter 'movie' or 'series': series
# Enter 'new' or 'expiring': new
