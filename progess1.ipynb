# %%
import requests

url = 'https://unogs-unogs-v1.p.rapidapi.com/api.cgi'
headers = {'x-rapidapi-host': 'unogs-unogs-v1.rapidapi.com',
          'x-rapidapi-key': '54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56'}
response = requests.get(url, headers=headers)
print(response.text)
# Out:
# ERROR: you can't get there from here!

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/api.cgi"

headers = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': "54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# ERROR: you can't get there from here!

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi"

querystring = {"q":"get:new7:US","p":"1","t":"ns","st":"adv"}

headers = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': "54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"COUNT":"52","ITEMS":[{"netflixid":"81260653","title":"My Stupid Boss 2","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABSXgfj-EiJ3RfiONvY0HzENhY93anBxSEzQIXECXdFczreolv_IMCsNr2j78i3TXg5guf3ZxhtXrJtwUIu5sJKCIIA.jpg?r=714","synopsis":"Having driven away many of his employees, Bossman and three of his long-suffering workers try to find cheap labor in Vietnam but find trouble instead.<br><b>New on 2020-04-23</b>","rating":"6.8","type":"movie","released":"2019","runtime":"1h34m","largeimage":"","unogsdate":"2020-04-23","imdbid":"tt10039468","download":"0"},{"netflixid":"81260652","title":"My Stupid Boss","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYgv3_lrD1MxoM2x3CqFzL4sfYxhiA3h4OC4tJmewzpS-eOyBzenNfqvWLvGZycSpcnqdzBec3t58kxBp-L1W2tK-g.jpg?r=59e","synopsis":"After moving to Kuala Lumpur, Diana lands a secretary job at an ironworks owned by her husband&#39;s old college friend, possibly the world&#39;s worst boss.<br><b>New on 2020-04-23</b>","rating":"7.3","type":"movie","released":"2016","runtime":"1h46m","largeimage":"","unogsdate":"2020-04-23","imdbid":"tt5514296","download":"0"},{"netflixid":"80230399","title":"Extraction","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABZRGH82QcZpJ5KWFei6m2zRGasTInV0ve0Fjhdu21IcFGACtEBppLPQQeCZ43VQtJ_XaKtJNrMxjiQ0jmO3pFJr-rtoyiV_DWIlaMAm77GTAlebNUoJPF5c7Lbg.jpg?r=a72","synopsis":"A hardened mercenary&#39;s mission becomes a soul-searching race to survive when he&#39;s sent into Bangladesh to rescue a drug lord&#39;s kidnapped son.<br><b>New on 2020-04-24</b>","rating":"0","type":"movie","released":"2020","runtime":"1h57m","largeimage":"","unogsdate":"2020-04-24","imdbid":"tt8936646","download":"0"},{"netflixid":"70258566","title":"DreamWorks Spooky Stories: Volume 2","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYWRmtuqCHgf79LyPwQFJoNb42B3TDyQwq6SjCUu93xfGmVwFg7WASFZmk2-rGOAGsiN8wF1TbeiKdbu-3nIAajGqw.jpg?r=c0e","synopsis":"The Shrek characters parody the music video &#39;Thriller&#39;; B.O.B. and pals battle zombie carrots; and Megamind faces the effects of the Button of Doom.<br><b>New on 2020-04-24</b>","rating":"6.7","type":"series","released":"2009","runtime":"","largeimage":"http://cdn1.nflximg.net/images/5323/11595323.jpg","unogsdate":"2020-04-24","imdbid":"tt3608838","download":"1"},{"netflixid":"81080697","title":"Love 101","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABS0PwsFzQqTQTud-VhloKKfsEqcDRMPkgpud6eenaCClUIW2Po-pmrawr_xEgwNu8_7Ca2FsNwnVc1Yol5oBdmR4RQzXeWdIbcfCVgRB2uZ1M_yM0-LXXrOEdN4.jpg?r=3e9","synopsis":"While trying to make their teacher fall for a basketball coach, four misfits and a model student find friendship, love and the courage to be themselves.<br><b>New on 2020-04-24</b>","rating":"","type":"series","released":"2020","runtime":"","largeimage":"","unogsdate":"2020-04-24","imdbid":"","download":"0"},{"netflixid":"70215452","title":"Mirror Mirror","image":"https://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABdCHFmjUCopJ8_LlhqFifQOMHuh6Xr27wKDRIZ-pDnN489N4rMVOBHiaKE50sc3vf3YvMOTSGK1XlBVmQbJUfhLIMg.jpg?r=cd9","synopsis":"This remake of the classic Grimm tale follows fair-skinned Snow White on a quest to regain her royal throne with help from a team of shady dwarves.<br><b>New on 2020-04-24</b>","rating":"5.6","type":"movie","released":"2012","runtime":"1h41m","largeimage":"http://cdn0.nflximg.net/images/0936/9290936.jpg","unogsdate":"2020-04-24","imdbid":"tt1667353","download":"1"},{"netflixid":"81111733","title":"Yours Sincerely, Kanan Gill","image":"http://occ-0-2717-360.1.nflxso.net/dnm/api/v6/evlCitJPPCVCry0BZlEFb5-QjKc/AAAABYiJhHzlHAwBBN2kJ7x1dtIwN4GyJ2Hc-4yj34i02E3YurYVNEtsWrT3ZgihUkcU0Z0Y9LAqOArxP62g4tXcMg35xJ1M_T4qN-bzQbR2znqBQSnOLdYTb9_U8D0.jpg?r=331","synopsis":"Revisiting life goals set in a letter written as a teen to his f ...

# %%
import requests

url = "https://unogs-unogs-v1.p.rapidapi.com/aaapi.cgi"

querystring = {"q":"get:new7:US","p":"1","t":"ns","st":"adv"}

headers = {
    'x-rapidapi-host': "unogs-unogs-v1.p.rapidapi.com",
    'x-rapidapi-key': "54f73deac1msh691cb562e1bb8aep1cf72fjsn3d1b8e92ed56"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
